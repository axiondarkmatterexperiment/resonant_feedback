# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os
from matplotlib.ticker import ScalarFormatter
from matplotlib import animation, rc
from IPython.display import HTML

def last_7chars(x):
    return(x[-7:])

rc('animation', html='html5')
fig,ax = plt.subplots(figsize=(13,6))
directory = '/Users/chelseabartram/Desktop/thrufilter_mixup/'

i=0
cutoff=2000
startpoint=3
file_list=os.listdir(directory)
giantarray=[]
for fname in sorted(file_list, key=last_7chars):
    i=i+1
    if(i<startpoint):
        continue
    if(i==cutoff):
        break
    ffname = directory+fname
    df=pd.read_csv(ffname,delimiter=",",names=['freq','dB'],parse_dates=False, dtype=np.float64)
    x=df['freq']
    myf = np.array(x*1e-6)
    y = df['dB']
    mydb = np.array(y)
    plt.xlabel('Freq (MHz)')
    plt.ylabel('Power')
    giantarray.append(mydb)

    
plt.plot(myf,giantarray[0],label=fname,c='white')     
line, = ax.plot([], [], lw=2) 
def init():
    line.set_data([],[])
    return(line,)
def animate(i):
    line.set_data(myf,giantarray[i])
    return (line,)
numframes=47
#numframes=10
anim = animation.FuncAnimation(fig, animate, init_func=init,frames=numframes, interval=100, blit=True)
    


#plt.legend(loc='best')                                                                                                                                                                
x_formatter = ScalarFormatter(useOffset=False)
ax.xaxis.set_major_formatter(x_formatter)
plt.ylim(-130,-50)
plt.savefig('TuneAfterFilter.png')
#plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))                                                                                                                          
x_formatter = ScalarFormatter(useOffset=False)
ax.xaxis.set_major_formatter(x_formatter)
anim
#plt.show()
# Out:
# <video width="936" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os
from matplotlib.ticker import ScalarFormatter
from matplotlib import animation, rc
from IPython.display import HTML

def last_7chars(x):
    return(x[-7:])

rc('animation', html='html5')
fig,ax = plt.subplots(figsize=(13,6))
#directory = '/Users/chelseabartram/Desktop/thrufilter_mixup/'
directory = '/Users/chelseabartram/Desktop/mixtorf/'
i=0
cutoff=2000
startpoint=3
file_list=os.listdir(directory)
giantarray=[]
for fname in sorted(file_list, key=last_7chars):
    i=i+1
    if(i<startpoint):
        continue
    if(i==cutoff):
        break
    ffname = directory+fname
    df=pd.read_csv(ffname,delimiter=",",names=['freq','dB','a','b','c'],parse_dates=False, dtype=np.float64)
    x=df['freq']
    myf = np.array(x*1e-6)
    y = df['dB']
    mydb = np.array(y)
    plt.xlabel('Freq (MHz)')
    plt.ylabel('Power')
  #  if(i==startpoint):
  #      plt.plot(myf,mydb,label=fname)   
    #print(mydb)
    giantarray.append(mydb)

    
plt.plot(myf,giantarray[0],label=fname,c='white')     
line, = ax.plot([], [], lw=2) 
def init():
    line.set_data([],[])
    return(line,)
def animate(i):
    line.set_data(myf,giantarray[i])
    return (line,)
#numframes=47
numframes=39
anim = animation.FuncAnimation(fig, animate, init_func=init,frames=numframes, interval=100, blit=True)
    


#plt.legend(loc='best')                                                                                                                                                                
x_formatter = ScalarFormatter(useOffset=False)
ax.xaxis.set_major_formatter(x_formatter)
plt.ylim(-130,-50)
plt.savefig('TuneAfterFilter.png')
#plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))                                                                                                                          
x_formatter = ScalarFormatter(useOffset=False)
ax.xaxis.set_major_formatter(x_formatter)
anim
#plt.show()
# Out:
# <video width="936" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
